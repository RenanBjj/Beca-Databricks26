-- %%
CREATE SCHEMA IF NOT EXISTS hive_metastore.renan_marques;

-- %%
CREATE OR REPLACE TABLE hive_metastore.renan_marques.portes
USING DELTA
LOCATION '/FileStore/RenanMarques/Job_Databricks_SP'
AS
SELECT * FROM delta.`/FileStore/RenanMarques/PORTES_2025_delta`
